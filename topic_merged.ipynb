# %% [markdown]
# # 在精细聚类的基础上进一步完成层次合并

# %%
import os
# 1. 设置国内镜像源
os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'
from bertopic import BERTopic
import torch # 新增：导入PyTorch（sentence_transformers的底层）
from sentence_transformers import SentenceTransformer
from umap import UMAP
from hdbscan import HDBSCAN
from sklearn.feature_extraction.text import CountVectorizer
import pickle

# %%
## 直接加载初始模型
topic_model = BERTopic.load(r"results\topic_models\bertopic_patents_zf_amb_V4")
print("初始主题模型加载成功！")
# 查看聚类结果
topic_model.get_topic_info()
# Out:
# 初始主题模型加载成功！
#       Topic  Count                                               Name  \
# 0        -1  44228                      -1_cell_comprises_agent_cells
# 1         0   1392                      0_6c_substituted_alkyl_cancer
# 2         1   1115  1_magnetic resonance_mri_resonance_resonance i...
# 3         2    690  2_target nucleic_primer_target nucleic acid_nu...
# 4         3    684         3_monomer_polymer_polymerization_copolymer
# ...     ...    ...                                                ...
# 1119   1118     20            1118_nemo_snrna_bicyclic_disulfide bond
# 1120   1119     20  1119_focal plane_plane array_focal plane array...
# 1121   1120     20  1120_protease_protease substrate_second part_p...
# 1122   1121     20                 1121_vif_lentivirus_lentiviral_hiv
# 1123   1122     20         1122_wake_go_thread_data processing system
#
#                                          Representation  \
# 0     [cell, comprises, agent, cells, protein, disea...
# 1     [6c, substituted, alkyl, cancer, optionally su...
# 2     [magnetic resonance, mri, resonance, resonance...
# 3     [target nucleic, primer, target nucleic acid, ...
# 4     [monomer, polymer, polymerization, copolymer, ...
# ...                                                 ...
# 1119  [nemo, snrna, bicyclic, disulfide bond, peptid...
# 1120  [focal plane, plane array, focal plane array, ...
# 1121  [protease, protease substrate, second part, pr...
# 1122  [vif, lentivirus, lentiviral, hiv, transcripti...
# 1123  [wake, go, thread, data processing system, dat...
#
#                                     Representative_Docs
# 0     [Novel peptide such as erythropoietin useful a...
# 1     [New amine compounds are phosphatidylinositol-...
# 2     [Method for magnetic resonance image reconstru...
# 3     [Detecting target nucleic acid sequence, by co...
# 4     [Production of polyolefin composition involves...
# ...                                                 ...
# 1119  [New bicyclic peptide, for preparing pharmaceu...
# 1120  [High-density composite focal plane array for ...
# 1121  [Screening for modulators of an intramembrane ...
# 1122  [New isolated nucleic acid molecule comprising...
# 1123  [Wake-and-go operation performing method for s...
#
# [1124 rows x 5 columns]

# %%
hierarchical_topics = topic_model.hierarchical_topics(docs)
hierarchical_clustering = topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
